# %%
PROJ_NAME = "kyber_indcca_dec_ttest"
LABEL = ""
PRNG_OFF = False
N = 100000
OFFSET = 350000
FROM_MEM = False

# %%
import sys
sys.path.insert(0, "../")
from host import ttest_analysis
# %matplotlib widget

# %%
ttest_analysis_obj = ttest_analysis.TTestAnalysis(PROJ_NAME, offset=OFFSET, label=LABEL, N=N, prng_off=PRNG_OFF, init_ths=not FROM_MEM)
# Out:
# Trace Header Set:
# Name.............: ETS Format THS
# Reader...........: ETS format reader of file traces/kyber_indcca_dec_ttest_N100000_prngoff0_r0_o350000_.ets with 173 traces.
# s................: uint8
#
# Trace Header Set:
# Name.............: ETS Format THS
# Reader...........: ETS format reader of file traces/kyber_indcca_dec_ttest_N100000_prngoff0_r1_o350000_.ets with 184 traces.
# s................: uint8

# %%
if FROM_MEM:
    ttest_analysis_obj.load_ttest_results()

# %%
# %matplotlib widget
ttest_analysis_obj.plot_means(size=(14, 6), num_traces=100)
# Out:
# /home/toluntosun/miniconda3/envs/sca/lib/python3.12/site-packages/traitlets/traitlets.py:1385: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   warn(
# <Axes: title={'center': 'Mean Traces'}>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
if not FROM_MEM:
    ttest_analysis_obj.read_ths()
    ttest_analysis_obj.run_ttest(chunk=5000, force_equal=False)
    ttest_analysis_obj.plot_ttest(ylimit=10)
else:
    ttest_analysis_obj.plot_ttest(ylimit=10)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
if not FROM_MEM:
    ttest_analysis_obj.live_update_ttest(refresh_interval=1, chunk=5000, force_equal=False, ylimit=10, hline_val=4.5)
# Out:
# /home/toluntosun/miniconda3/envs/sca/lib/python3.12/site-packages/traitlets/traitlets.py:1385: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   warn(
# Live monitor started. Call stop_live_update() to stop.
# Running T-Test:   0%|          | 0/1 [00:00<?, ?it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Running T-Test: 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
# Exception in thread Thread-4 (worker):
# Traceback (most recent call last):
#   File "/home/toluntosun/miniconda3/envs/sca/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/home/toluntosun/miniconda3/envs/sca/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
# ...

# %%
# to stop live results update
# ttest_analysis_obj._stop_live = True

# %%
if not FROM_MEM:
    ttest_analysis_obj.save_ttest_results()
