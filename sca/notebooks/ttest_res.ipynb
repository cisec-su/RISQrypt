# %%
PROJ_NAME = "kyber_indcca_dec_ttest"
LABEL = ""
PRNG_OFF = False
N = 100000

# %%
import sys
sys.path.insert(0, "../")
from host import ttest_trace_collector
# %matplotlib widget

# %%
trace_collector = ttest_trace_collector.TTestTraceCollector(proj_name=PROJ_NAME, label=LABEL)

# %%
ttest_analysis = trace_collector.get_analysis_obj(N=N, prng_off=PRNG_OFF)
# Out:
# Trace Header Set:
# Name.............: ETS Format THS
# Reader...........: ETS format reader of file traces/kyber_indcca_dec_ttest_N100000_prngoff0_r0_ with 4665 traces.
# s................: float64
#
# Trace Header Set:
# Name.............: ETS Format THS
# Reader...........: ETS format reader of file traces/kyber_indcca_dec_ttest_N100000_prngoff0_r1_ with 4665 traces.
# s................: float64

# %%
ttest_analysis.plot_means(num_traces=100)
# Out:
# /home/toluntosun/miniconda3/envs/sca/lib/python3.12/site-packages/traitlets/traitlets.py:1385: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   warn(
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ttest_analysis.plot_traces()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ttest_analysis.run_ttest()

# %%
ttest_analysis.plot_ttest(ylimit=10)
# Out:
# /home/toluntosun/miniconda3/envs/sca/lib/python3.12/site-packages/traitlets/traitlets.py:1385: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   warn(
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
