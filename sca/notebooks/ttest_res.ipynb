# %%
PROJ_NAME = "dilithium_poly_decompose_ttest"
LABEL = "param_large_init_onlya2b_1lt4"
PRNG_OFF = False
N = 100000
OFFSET = 0

# %%
import sys
sys.path.insert(0, "../")
from host import ttest_trace_collector
# %matplotlib widget

# %%
trace_collector = ttest_trace_collector.TTestTraceCollector(proj_name=PROJ_NAME, label=LABEL, offset=OFFSET)

# %%
ttest_analysis = trace_collector.get_analysis_obj(N=N, prng_off=PRNG_OFF)
# Out:
# Trace Header Set:
# Name.............: ETS Format THS
# Reader...........: ETS format reader of file traces/dilithium_poly_decompose_ttest_N100000_prngoff0_r0_o0_param_large_init_onlya2b_1lt4.ets with 100000 traces.
# s................: float64
#
# Trace Header Set:
# Name.............: ETS Format THS
# Reader...........: ETS format reader of file traces/dilithium_poly_decompose_ttest_N100000_prngoff0_r1_o0_param_large_init_onlya2b_1lt4.ets with 100000 traces.
# s................: float64

# %%
ttest_analysis.plot_means(num_traces=100)
# Out:
# /home/toluntosun/miniconda3/envs/sca/lib/python3.12/site-packages/traitlets/traitlets.py:1385: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   warn(
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ttest_analysis.plot_traces()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ttest_analysis.run_ttest(chunk=5000)
# Out:
# Running T-Test: 100%|██████████| 20/20 [00:06<00:00,  3.28it/s]

# %%
ttest_analysis.plot_ttest(ylimit=10)
# Out:
# /home/toluntosun/miniconda3/envs/sca/lib/python3.12/site-packages/traitlets/traitlets.py:1385: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   warn(
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ttest_analysis.save_ttest_results()
