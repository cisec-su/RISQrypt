# %%
PROJ_NAME = "kyber_poly_get_noise_ttest"
LABEL = ""
N_OFF = 1000
N_ON = 100000
OFFSET = 0

# %%
import sys
sys.path.insert(0, "../")
from host import ttest_trace_collector
# %matplotlib widget

# %%
trace_collector = ttest_trace_collector.TTestTraceCollector(proj_name=PROJ_NAME, label=LABEL, offset=OFFSET)

# %%
ttest_analysis_on  = trace_collector.get_analysis_obj(N=N_ON, prng_off=False)
ttest_analysis_off = trace_collector.get_analysis_obj(N=N_OFF, prng_off=True)
# Out:
# Trace Header Set:
# Name.............: ETS Format THS
# Reader...........: ETS format reader of file traces/kyber_poly_get_noise_ttest_N100000_prngoff0_r0_o0_ with 100000 traces.
# s................: float64
#
# Trace Header Set:
# Name.............: ETS Format THS
# Reader...........: ETS format reader of file traces/kyber_poly_get_noise_ttest_N100000_prngoff0_r1_o0_ with 100000 traces.
# s................: float64
#
# Trace Header Set:
# Name.............: ETS Format THS
# Reader...........: ETS format reader of file traces/kyber_poly_get_noise_ttest_N1000_prngoff1_r0_o0_ with 1000 traces.
# s................: float64
#
# Trace Header Set:
# Name.............: ETS Format THS
# Reader...........: ETS format reader of file traces/kyber_poly_get_noise_ttest_N1000_prngoff1_r1_o0_ with 1000 traces.
# s................: float64

# %%
ttest_analysis_on.run_ttest()
ttest_analysis_off.run_ttest()
# Out:
# ...
# Running T-Test:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from matplotlib import pyplot as plt
fig, ax = plt.subplots()
ttest_analysis_off.plot_ttest(ylimit=10, ax=ax, color='gray', plt_show=False, put_title=False, put_label=False)
ttest_analysis_on.plot_ttest(ylimit=10, ax=ax, color='black', plt_show=False, put_title=False, put_label=False)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
fig.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
