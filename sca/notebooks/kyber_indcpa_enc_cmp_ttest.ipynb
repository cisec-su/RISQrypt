# %%
PROJ_NAME = "kyber_indcpa_enc_cmp_ttest"
LABEL = ""
OFFSET = 0

# %%
import sys
sys.path.insert(0, "../")
from host.ttest_trace_collector import TTestTraceCollector

# %%
trace_collector = TTestTraceCollector(proj_name=PROJ_NAME, label=LABEL, input_len=32, output_len=0, offset=OFFSET)

# %%
trace_collector.init_target(force=True)
# Out:
# (ChipWhisperer NAEUSB WARNING|File naeusb.py:800) Your firmware (0.51) is outdated - latest is 0.53 See https://chipwhisperer.readthedocs.io/en/latest/firmware.html for more information

# %%
trace_collector.default_setup(40E6, 12, 120000, mul=4)

# %%
trace_collector.build_fw()
trace_collector.program_fw()
# Out:
# -DKYBER_K=3 -DSS_VER=1 -O3 -I../../../../fw/kyber_hw -I../victims_commons -I../../driver -I../../simpleserial -I../../../../sdk/lib -march=rv32im -mabi=ilp32 -mstrict-align -T ../../../../sdk/toolchain/linksc.ld -flto -ffunction-sections -fdata-sections -nostartfiles -o kyber_indcpa_enc_cmp_ttest.elf
# /opt/riscv/bin/riscv64-unknown-elf-gcc kyber_indcpa_enc_cmp_ttest.c ../../../../fw/kyber_hw/indcpa.c ../../../../fw/kyber_hw/poly.c ../../../../fw/kyber_hw/polyvec.c ../../../../fw/kyber_hw/pack.c ../../../../fw/kyber_hw/symmetric.c ../../../../fw/kyber_hw/cbd.c ../../../../fw/kyber_hw/masked_indcpa.c ../../../../fw/kyber_hw/masked_poly.c ../../../../fw/kyber_hw/masked_polyvec.c ../../../../fw/kyber_hw/masked_symmetric.c ../../../../fw/kyber_hw/masked_cbd.c ../../../../fw/kyber_hw/masked_gadgets.c ../victims_commons/victims_commons_util.c ../victims_commons/victims_commons_kyber.c ../../driver/cw305.c ../../driver/x2x_prng.c ../../simpleserial/simpleserial_cw305_rq.c ../../../../sdk/toolchain/start.s ../../../../sdk/lib/util.c ../../../../sdk/lib/uart.c ../../../../sdk/lib/timer.c ../../../../sdk/lib/gpio.c ../../../../sdk/lib/keccak.c ../../../../sdk/lib/ntt_lite.c ../../../../sdk/lib/x2x.c -DKYBER_K=3 -DSS_VER=1 -O3 -I../../../../fw/kyber_hw -I../victims_commons -I../../driver -I../../simpleserial -I../../../../sdk/lib -march=rv32im -mabi=ilp32 -mstrict-align -T ../../../../sdk/toolchain/linksc.ld -flto -ffunction-sections -fdata-sections -nostartfiles -o kyber_indcpa_enc_cmp_ttest.elf
# /opt/riscv/bin/riscv64-unknown-elf-objcopy -O binary -j .init   -j .text kyber_indcpa_enc_cmp_ttest.elf kyber_indcpa_enc_cmp_ttest.inst.bin
# /opt/riscv/bin/riscv64-unknown-elf-objcopy -O binary -j .rodata -j .data kyber_indcpa_enc_cmp_ttest.elf kyber_indcpa_enc_cmp_ttest.data.bin
# python3 ../../../../sdk/toolchain/rom_generator.py kyber_indcpa_enc_cmp_ttest.inst.bin kyber_indcpa_enc_cmp_ttest.inst.mem
# python3 ../../../../sdk/toolchain/rom_generator.py kyber_indcpa_enc_cmp_ttest.data.bin kyber_indcpa_enc_cmp_ttest.data.mem
# /opt/riscv/bin/riscv64-unknown-elf-size -B kyber_indcpa_enc_cmp_ttest.elf
#    text	   data	    bss	    dec	    hex	filename
#   12896	   1184	   3876	  17956	   4624	kyber_indcpa_enc_cmp_ttest.elf
# Successfully connected to /dev/ttyUSB0
# Sent: -p
# Waiting for opcodes...
# Sending file: ../fw/victims/kyber_indcpa_enc_cmp_ttest/kyber_indcpa_enc_cmp_ttest.inst.bin
# ../fw/victims/kyber_indcpa_enc_cmp_ttest/kyber_indcpa_enc_cmp_ttest.inst.bin: 100%|██████████| 10.3k/10.3k [00:10<00:00, 1.02kB/s]
# ../fw/victims/kyber_indcpa_enc_cmp_ttest/kyber_indcpa_enc_cmp_ttest.data.bin:   0%|          | 0.00/3.82k [00:00<?, ?B/s]
# File transmission complete for ../fw/victims/kyber_indcpa_enc_cmp_ttest/kyber_indcpa_enc_cmp_ttest.inst.bin.
# Sending file: ../fw/victims/kyber_indcpa_enc_cmp_ttest/kyber_indcpa_enc_cmp_ttest.data.bin
# ../fw/victims/kyber_indcpa_enc_cmp_ttest/kyber_indcpa_enc_cmp_ttest.data.bin: 100%|██████████| 3.82k/3.82k [00:03<00:00, 1.02kB/s]
# File transmission complete for ../fw/victims/kyber_indcpa_enc_cmp_ttest/kyber_indcpa_enc_cmp_ttest.data.bin.
# Program load complete.
# Serial port closed.

# %% [markdown]
# # PRNG=OFF

# %%
trace_collector.collect_traces(N=1000, prng_off=True, overwrite=True, check_output=False, init_input=False)
# Out:
# Capturing traces:   0%|          | 0/1000 [00:00<?, ?it/s]
# ERROR:estraces.formats.ets_writer:Exception raised during init of h5f file: [Errno 2] Unable to synchronously open file (unable to open file: name = 'traces/kyber_indcpa_enc_cmp_ttest_N1000_prngoff1_r0_o0_.ets', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0).
# ERROR:estraces.formats.ets_writer:Exception raised during init of h5f file: [Errno 2] Unable to synchronously open file (unable to open file: name = 'traces/kyber_indcpa_enc_cmp_ttest_N1000_prngoff1_r1_o0_.ets', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0).

# %%
ttest_analysis = trace_collector.get_analysis_obj(N=1000, prng_off=True)
# Out:
# Trace Header Set:
# Name.............: ETS Format THS
# Reader...........: ETS format reader of file traces/kyber_indcpa_enc_cmp_ttest_N1000_prngoff1_r0_o0_.ets with 1000 traces.
# s................: float64
#
# Trace Header Set:
# Name.............: ETS Format THS
# Reader...........: ETS format reader of file traces/kyber_indcpa_enc_cmp_ttest_N1000_prngoff1_r1_o0_.ets with 1000 traces.
# s................: float64

# %%
ttest_analysis.plot_means()

# %%
ttest_analysis.plot_traces()

# %%
ttest_analysis.run_ttest()
# Out:
# Running T-Test:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# %matplotlib widget
ttest_analysis.plot_ttest()
# Out:
# /home/toluntosun/miniconda3/envs/sca/lib/python3.12/site-packages/traitlets/traitlets.py:1385: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   warn(
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # PRNG=ON

# %%
trace_collector.collect_traces(N=1000, prng_off=False, overwrite=True, check_output=False, init_input=False)
# Out:
# Capturing traces:   0%|          | 0/1000 [00:00<?, ?it/s]
# ERROR:estraces.formats.ets_writer:Exception raised during init of h5f file: [Errno 2] Unable to synchronously open file (unable to open file: name = 'traces/kyber_indcpa_enc_cmp_ttest_N1000_prngoff0_r0_o0_.ets', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0).
# ERROR:estraces.formats.ets_writer:Exception raised during init of h5f file: [Errno 2] Unable to synchronously open file (unable to open file: name = 'traces/kyber_indcpa_enc_cmp_ttest_N1000_prngoff0_r1_o0_.ets', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0).

# %%
ttest_analysis = trace_collector.get_analysis_obj(N=1000, prng_off=False)
# Out:
# Trace Header Set:
# Name.............: ETS Format THS
# Reader...........: ETS format reader of file traces/kyber_indcpa_enc_cmp_ttest_N1000_prngoff0_r0_o0_.ets with 1000 traces.
# s................: float64
#
# Trace Header Set:
# Name.............: ETS Format THS
# Reader...........: ETS format reader of file traces/kyber_indcpa_enc_cmp_ttest_N1000_prngoff0_r1_o0_.ets with 1000 traces.
# s................: float64

# %%
ttest_analysis.plot_means()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ttest_analysis.plot_traces()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ttest_analysis.run_ttest()
# Out:
# Running T-Test:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
ttest_analysis.plot_ttest(ylimit=10)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
